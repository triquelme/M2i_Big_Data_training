# %%
import pandas as pd
import json
#import re
#from unidecode import unidecode
#import numpy as np

from elasticsearch import helpers, Elasticsearch

#Index pour le test    
raw_index = 'restaurants'

#Se connecter à elastic
host="localhost"  
port=9200
          
es = Elasticsearch(hosts = [{'host': host, 'port': 9200}])

# %%
def create_index(es_instance, _index):
    request_body = {
        "settings" : {
            "number_of_shards": 5,
            "number_of_replicas": 2
        },
          "mappings": {
           # "_doc": { 
              "properties": { 
                "address": { 
                    "properties": {
                        "building": { "type": "text" },
                        "coord": { "type": "geo_point" },
                        "street": { "type": "text" },
                        "zipcode": { "type": "text" }}}, 
                "borough": { "type": "text" }, 
                "cuisine": { "type": "text" } ,
                "grades": { "type": "nested" }, 
                "name": { "type": "text" }, 
                "restaurant_id": { "type": "text" }
              }}
    #}
    }

    print("creating index...")
    es_instance.indices.create(index = _index, body = request_body)

#es.indices.delete(index=raw_index, ignore=[400, 404])
create_index(es, raw_index)
# Out:
# creating index...
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# <ipython-input-19-11434b71b395> in <module>
#      27
#      28 #es.indices.delete(index=raw_index, ignore=[400, 404])
# ---> 29 create_index(es, raw_index)
#
# <ipython-input-19-11434b71b395> in create_index(es_instance, _index)
#      24
#      25     print("creating index...")
# ---> 26     es_instance.indices.create(index = _index, body = request_body)
#      27
#      28 #es.indices.delete(index=raw_index, ignore=[400, 404])
#
# c:\users\afifa\appdata\local\programs\python\python38\lib\site-packages\elasticsearch\client\utils.py in _wrapped(*args, **kwargs)
#      90                 if p in kwargs:
#      91                     params[p] = kwargs.pop(p)
# ---> 92             return func(*args, params=params, headers=headers, **kwargs)
#      93
#      94         return _wrapped
#
# c:\users\afifa\appdata\local\programs\python\python38\lib\site-packages\elasticsearch\client\indices.py in create(self, index, body, params, headers)
#     101             raise ValueError("Empty value passed for a required argument 'index'.")
#     102
# --> 103         return self.transport.perform_request(
#     104             "PUT", _make_path(index), params=params, headers=headers, body=body
#     105         )
#
# c:\users\afifa\appdata\local\programs\python\python38\lib\site-packages\elasticsearch\transport.py in perform_request(self, method, url, headers, params, body)
#     353
#     354             try:
# --> 355                 status, headers_response, data = connection.perform_request(
#     356                     method,
#     357                     url,
#
# c:\users\afifa\appdata\local\programs\python\python38\lib\site-packages\elasticsearch\connection\http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     246                 method, full_url, url, orig_body, duration, response.status, raw_data
#     247             )
# --> 248             self._raise_error(response.status, raw_data)
#     249
#     250         self.log_request_success(
#
# c:\users\afifa\appdata\local\programs\python\python38\lib\site-packages\elasticsearch\connection\base.py in _raise_error(self, status_code, raw_data)
#     241             logger.warning("Undecodable raw error response from server: %s", err)
#     242
# --> 243         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     244             status_code, error_message, additional_info
#     245         )
#
# RequestError: RequestError(400, 'resource_already_exists_exception', 'index [restaurants/dzHQFXSsQbaKzO95_T9YnQ] already exists')

# %%
def write_to_index(es,index_name, df, bulk_size, doc_type): 
    bulk_size = 10
    bulk_data = []
    
  
    for idx, row in df.iterrows():
        data_dict = {}
        
        for i in range(len(row)):
            data_dict[df.columns[i]] = str(row[i])
       
        
        op_dict = {
            "index": {
                "_index": index_name,
#                "_type": doc_type
            }
        }
        bulk_data.append(op_dict)
        bulk_data.append(data_dict)
        
        if (idx+1)%bulk_size==0:
            res = es.bulk(index=index_name,body=bulk_data, refresh = True, request_timeout=200)
            print('filling index')
            bulk_data=[]
        
    if len(bulk_data)>0:
        res = es.bulk(index=index_name,body=bulk_data, refresh = True, request_timeout=200)
    print('done.')


    
restaurants = []
for element in open('restaurants.json', 'r'):
    restaurants.append(json.loads(element))

df = pd.DataFrame(restaurants)
    
#df = pd.read_json('restaurants.json', orient='split', lines=True)
#df.columns =  columns = ['title','seo_title','url','author','date','category','locales', 'content']    
    
bulk_size = 10   
doc_type = '_doc'        
index = 'restaurants' 
write_to_index(es,index, df, bulk_size, doc_type)
# Out:
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index
# filling index

# %%
#from elasticsearch import Elasticsearch
#es = Elasticsearch(cloud_id = "my_cluster:ZXUtY2VudHJhbC0xLmF3cy5jbG91ZC5lcy5pbyRkZmYxYzNlZjVjZjA0MzMxODM1OWVkMWRkNGUzMTQwYSRiZWUzMjYzNjFiMGQ0ZWNhYmJhNmMwNDBjNGRhNTZjOA==",http_auth=('elastic', '8bxTFCpLEOH0rm0FIexD2XYH'))
