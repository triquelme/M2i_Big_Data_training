# %% [markdown]
# # Qu'est ce que BeautifulSoup

# %% [markdown]
# Beautiful Soup est la meilleure bibliothèque pour supprimer les données d'un site Web particulier ou d'Internet. Et il est très confortable de travailler aussi. Il analyse et extrait des données structurées à partir de HTML. Beautiful Soup transforme automatiquement les textes entrants en Unicode et les versions sortantes en UTF-8. Vous ne devez pas vous rappeler d’encodages sauf que le document ne définit pas d’encodage et que Beautiful Soup ne peut pas en attraper un. Ensuite, vous devez mentionner le codage d'origine.

# %% [markdown]
# # Basic-Getting Familiar with HTML

# %% [markdown]
# HTML code plays an essential role in extracting data from the website. So, before we processed, let us jump to the basic of the HTML tags. If you have got a tiny bit of knowledge of HTML tags, you can move ahead to the next level.

# %% [markdown]
#                                         <!DOCTYPE html>
#                                         <html>
#                                             <head>
#                                             </head>
#                                             <body>
#                                                 <h1> Learning about Data</h1>
#                                                 <p> Beautiful Soup</p>
#                                             <body>
#                                         </html>

# %% [markdown]
#     This is the basic syntax of an HTML webpage. Every <tag> serves a block inside the webpage:
#     1. <!DOCTYPE html>: HTML documents must start with a type declaration.
#     2. The HTML document is contained between <html> and </html>.
#     3. The meta and script declaration of the HTML document is between <head> and </head>.
#     4. The visible portion of the HTML document is between <body> and </body> tags.
#     5. Title headings are defined with the <h1> through <h6> tags.
#     6. Paragraphs are defined with the <p> tag.
#     Other useful tags include <a> for hyperlinks, <table> for tables, <tr> for table rows, and <td> for table columns.

# %% [markdown]
# # Commençons votre projet de bricolage

# %% [markdown]
# Nous connaissons maintenant nos données et leur emplacement. Nous allons donc commencer à mettre nos données à la ferraille.
# Avant de procéder, vous devez installer ou importer certaines bibliothèques.

# %%
#Import Libraries
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Requests

# %% [markdown]
# Il est destiné à être utilisé par les humains pour communiquer avec le langage. Cela signifie que vous n'avez pas besoin de joindre manuellement les chaînes de requête aux URL, ni d'encoder de manière formelle vos données POST. Les demandes vous permettront d’envoyer des demandes HTTP / 1.1 à l’aide de Python. Vous pouvez y combiner du contenu tel que des en-têtes, des données de formulaire, des fichiers en plusieurs parties et des paramètres via de simples bibliothèques Python. Il vous permet également d’obtenir les données de réponse de Python de la même manière.

# %% [markdown]
# # BS4 — BeautifulSoup

# %% [markdown]
# Beautiful Soup est une bibliothèque Python pour extraire des données de fichiers HTML et XML. Il travaille avec votre analyseur préféré pour produire des méthodes naturelles d’exploitation, d’examen et de transformation de l’arbre d’analyse syntaxique. Cela épargne généralement des heures ou des jours de travail aux programmeurs.

# %%
# Specify with which URL/web page we are going to be scraping
html = requests.get('https://www.marmiton.org/recettes/recette_tacos-mexicains_34389.aspx').text
html
# Out:
# '\n<!DOCTYPE html>\n<html lang="fr" class="no-js">\n\t<head>\n\t\t\t\t\t\n<script>\nwindow.gdprAppliesGlobally=true;\n(function(){function n(){if(!window.frames.__cmpLocator){if(document.body&&document.body.firstChild){var e=document.body;var t=document.createElement("iframe");t.style.display="none";t.name="__cmpLocator";t.title="cmpLocator";e.insertBefore(t,e.firstChild)}else{setTimeout(n,5)}}}function e(e,t,n){if(typeof n!=="function"){return}\nif(!window.__cmpBuffer){window.__cmpBuffer=[]}if(e==="ping"){n({gdprAppliesGlobally:window.gdprAppliesGlobally,cmpLoaded:false},true)}else{window.__cmpBuffer.push({command:e,parameter:t,callback:n})}}e.stub=true;function t(r){if(!window.__cmp||window.__cmp.stub!==true){return}if(!r.data){return}var a=typeof r.data==="string";var e;try{e=a?JSON.parse(r.data):r.data}catch(t){return}if(e.__cmpCall){var o=e.__cmpCall;window.__cmp(o.command,o.parameter,function(e,t){var n={__cmpReturn:{returnValue:e,success:t,callId:o.callId}};r.source.postMessage(a?JSON.stringify(n):n,"*")})}}if(typeof window.__cmp!=="function"){window.__cmp=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}n()})();(function(e){var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];\nn.parentNode.insertBefore(t,n)})("0f196fe5-c7e1-4613-9c62-9be54399d640");\n\nwindow.didomiConfig = {\n  notice: {\n    position: \'banner\'\n  }\n};\nwindow.didomiOnReady = window.didomiOnReady || [];\nwindow.didomiOnReady.push(function cmpDidomiPushOnReady(Didomi) {\n  if(Didomi.notice.isVisible()) {\n    const maxScrollDepth = ((Didomi.getConfig()||{}).custom||{}).scrollDepth;\n    if(!maxScrollDepth)\n      return;\n    const startPositionScroll = window.scrollY;\n    var ticking = false;\n    window.addEventListener(\'scroll\', function cmpDidomiScrollListener(e) {\n      if (!ticking) {\n        window.requestAnimationFrame(function cmpDidomiCheckScrollDepth() {\n          if(!Didomi.notice.isVisible()){\n            window.removeEventListener(\'scroll\', cmpDidomiScrollListener);\n            return;\n          }\n          var lastPositionScroll = window.scrollY;\n          if (Math.abs(startPositionScroll - lastPositionScroll) >= maxScrollDepth) {\n              Didomi.setUserAgreeToAll();\n              window.removeEventListener(\'scroll\', cmpDidomiScrollListener);\n          }\n          ticking = false;\n        });\n        ticking = true;\n      }\n    });\n  }\n});\nvar showCmpPreferencesPopup = function(){ Didomi.preferences.show() };\n</script>\n\n\n\n\n\n\t\t\t    \n\t   \n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-aedcd3c03fde7213bd0",applicationID:"409934563"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e, ...

# %% [markdown]
# Nous commençons par étudier le code source d’une page Web donnée et par construire un objet BeautifulSoup (soup) avec la fonction BeautifulSoup.Maintenant, nous devons utiliser la fonction Beautiful Soap, qui nous aidera à analyser et à appliquer le code HTML extrait de notre page Wikipedia. :

# %% [markdown]
# Ensuite, nous allons utiliser Beautiful Soup pour analyser les données HTML que nous avons collectées dans notre variable "URL", puis nous affectons une variable différente pour stocker les données au format Beautiful Soup, appelé "Soupe".

# %%
#Parse the HTML from our URL into the BeautifulSoup parse tree format
html_parsé = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Pour connaître la structure du code HTML sous-jacent dans notre page Web, utilisez la fonction prettify de Beautiful Soup et vérifiez-la.

# %%
#To look at the HTML underlying to the web 
print(html_parsé.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="fr">
#  <head>
#   <script>
#    window.gdprAppliesGlobally=true;
# (function(){function n(){if(!window.frames.__cmpLocator){if(document.body&&document.body.firstChild){var e=document.body;var t=document.createElement("iframe");t.style.display="none";t.name="__cmpLocator";t.title="cmpLocator";e.insertBefore(t,e.firstChild)}else{setTimeout(n,5)}}}function e(e,t,n){if(typeof n!=="function"){return}
# if(!window.__cmpBuffer){window.__cmpBuffer=[]}if(e==="ping"){n({gdprAppliesGlobally:window.gdprAppliesGlobally,cmpLoaded:false},true)}else{window.__cmpBuffer.push({command:e,parameter:t,callback:n})}}e.stub=true;function t(r){if(!window.__cmp||window.__cmp.stub!==true){return}if(!r.data){return}var a=typeof r.data==="string";var e;try{e=a?JSON.parse(r.data):r.data}catch(t){return}if(e.__cmpCall){var o=e.__cmpCall;window.__cmp(o.command,o.parameter,function(e,t){var n={__cmpReturn:{returnValue:e,success:t,callId:o.callId}};r.source.postMessage(a?JSON.stringify(n):n,"*")})}}if(typeof window.__cmp!=="function"){window.__cmp=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}n()})();(function(e){var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];
# n.parentNode.insertBefore(t,n)})("0f196fe5-c7e1-4613-9c62-9be54399d640");
#
# window.didomiConfig = {
#   notice: {
#     position: 'banner'
#   }
# };
# window.didomiOnReady = window.didomiOnReady || [];
# window.didomiOnReady.push(function cmpDidomiPushOnReady(Didomi) {
#   if(Didomi.notice.isVisible()) {
#     const maxScrollDepth = ((Didomi.getConfig()||{}).custom||{}).scrollDepth;
#     if(!maxScrollDepth)
#       return;
#     const startPositionScroll = window.scrollY;
#     var ticking = false;
#     window.addEventListener('scroll', function cmpDidomiScrollListener(e) {
#       if (!ticking) {
#         window.requestAnimationFrame(function cmpDidomiCheckScrollDepth() {
#           if(!Didomi.notice.isVisible()){
#             window.removeEventListener('scroll', cmpDidomiScrollListener);
#             return;
#           }
#           var lastPositionScroll = window.scrollY;
#           if (Math.abs(startPositionScroll - lastPositionScroll) >= maxScrollDepth) {
#               Didomi.setUserAgreeToAll();
#               window.removeEventListener('scroll', cmpDidomiScrollListener);
#           }
#           ticking = false;
#         });
#         ticking = true;
#       }
#     });
#   }
# });
# var showCmpPreferencesPopup = function(){ Didomi.preferences.show() };
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-aedcd3c03fde7213bd0",applicationID:"409934563"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var a,f,c=e("handle"),u=e("loader"),s=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){a=new PerformanceObserver(r),f=new PerformanceObserver(i);try{a.observe({entryTypes:["paint"]}),f.observe({entryTypes:["largest-contentful-paint"]})}catch(p){}}if("addEventListener"in document){var l=!1,d=["click","keydown","mousedown","pointerdown","touchstart"];d.forEach(function(e){document.addEventListener(e,o,!1)})}}},{}],3:[function(e,n,t){function r(e,n){if(!i)return!1;if(e!==i)return!1;if(!n)return!0;if(!o)return!1;for(var t=o.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}n.exports={agent:i,version:o,match:r}},{}],4:[function(e,n,t){function r(e,n){var t=[],r="",o=0;for(r in e)i.call(e,r)&&(t[o]=n(r,e[r]),o+=1);return t}var i=Object.prototype.hasOwnProperty;n.exports=r},{}],5:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,i=t-n||0,o=Array(i<0?0:i);++r<i;)o[r]=e[n+r];return o}n.exports=r},{}],6:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function i(e){function n(e){return e&&e instanceof r?e:e?c(e,f,o):o()}function t(t,r,i,o){if(!l.aborted||o){e&&e(t,r,i);for(var a=n(i),f=v(t),c=f.length,u=0;u<c;u++)f[u].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function d(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||i(t)}function w(e,n){u(e,function(e,t){n=n||"feature", ...
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="max-snippet:-1" name="robots"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="max-video-preview:-1" name="robots"/>
#   <title>
#    Tacos mexicains : Recette de Tacos mexicains - Marmiton
#   </title>
#   <meta content="marmiton_opengraph:recipe" property="og:type">
#    <meta content="Tacos mexicains" property="og:title">
#     <meta content="tortilla, oignon blanc, tomate, coulis de tomate, boeuf haché, haricots rouges, poivron vert, laitue, cumin en poudre, poivre, sel..." property="og:description">
#      <meta content="https://assets.afcdn.com/recipe/20190212/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg" property="og:image">
#       <meta content="/recettes/recette_tacos-mexicains_34389.aspx" property="og:url">
#        <meta content="Marmiton" property="og:site_name">
#         <meta content="179380945463734" property="fb:app_id">
#          <meta content="summary_large_image" property="twitter:card"/>
#          <meta content="Tacos mexicains" property="twitter:title"/>
#          <meta content="tortilla, oignon blanc, tomate, coulis de tomate, boeuf haché, haricots rouges, poivron vert, laitue, cumin en poudre, poivre, sel..." property="twitter:description"/>
#          <meta content="https://assets.afcdn.com/recipe/20190212/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg" property="twitter:image:src"/>
#          <meta content="318796083" property="al:iphone:app_store_id"/>
#          <meta content="Marmiton" property="al:iphone:app_name"/>
#          <meta content="marmiton://recipe?id=34389" property="al:iphone:url"/>
#          <meta content="318796083" property="twitter:app:id:iphone"/>
#          <meta content="Marmiton" property="twitter:app:name:iphone"/>
#          <meta content="marmiton://recipe?id=34389" property="twitter:app:url:iphone"/>
#          <meta content="com.aufeminin.marmiton.activities" property="al:android:package"/>
#          <meta content="Marmiton" property="al:android:app_name"/>
#          <meta content="marmiton://recipe?id=34389" property="al:android:url"/>
#          <meta content="FR" property="twitter:app:country"/>
#          <meta content="com.aufeminin.marmiton.activities" property="twitter:app:id:googleplay"/>
#          <meta content="Marmiton" property="twitter:app:name:googleplay"/>
#          <meta content="marmiton://recipe?id=34389" property="twitter:app:url:googleplay"/>
#          <meta content="9387747946" property="fb:pages"/>
#          <meta content="fr_FR" property="og:locale"/>
#          <meta content="recettes, cuisine, recette, recettes de cuisine, testées, plat, entrée, dessert, plat de résistance, confiserie, boisson, cocktail" name="keywords"/>
#          <meta content="Recette de cuisine Marmiton" name="description"/>
#          <meta content="cuisine recettes gratuit" name="classification"/>
#          <meta content="marmiton.org" name="application-name"/>
#          <meta content="Ouvrir marmiton.org" name="msapplication-tooltip"/>
#          <meta content="/" name="msapplication-starturl"/>
#          <meta content="#ed6b06" name="msapplication-navbutton-color"/>
#          <meta content="app-id= 318796083" name="apple-itunes-app"/>
#          <meta content="Marmiton-aufeminin" name="author"/>
#          <meta content="index, follow" name="robots"/>
#          <meta content="(pics-1.1 &amp;amp;quot;http://www.icra.org/pics/vocabularyv03/&amp;amp;quot; l gen true for &amp;amp;quot;https://marmiton.org&amp;amp;quot; r (n 0 s 0 v 0 l 0 oa 0 ob 0 oc 0 od 0 oe 0 of 0 og 0 oh 0 c 1) gen true for &amp;amp;quot;https://www.marmiton.org&amp;amp;quot; r (n 0 s 0 v 0 l 0 oa 0 ob 0 oc 0 od 0 oe 0 of 0 og 0 oh 0 c 1) gen true for &amp;amp;quot;http://network.aufeminin.com&amp;amp;quot; r (n 0 s 0 v 0 l 0 oa 0 ob 0 oc 0 od 0 oe 0 of 0 og 0 oh 0 c 1) gen true for &amp;amp;quot;http://www.smartadserver.com&amp;amp;quot; r (n 0 s 0 v 0 l 0 oa 0 ob 0 oc 0 od 0 oe 0 of 0 og 0 oh 0 c 1))" name="pics-Label"/>
#          <script crossorigin="anonymous" src="https://static.afcdn.com/relmrtn/concat.js?PCM-lVNNb9swDP01OVpw7C5DDz2kK9pLD8E65FrQEmOrkUXBkpelv760inwocdMMsA3yPT6KpKklWkXdpHh0feX7io2pmIl8D2Re29pgICve_N1yF13RxuPBEK1OeehX_K0NVWBeJbUt2ddAbiQGVs9U15xijHpB7zWNpoZRwQJqfHGI6kLSuaoMyXXCOTLblTaGTWnAe6N9-K6hhG-hazVPaTC7YLOWFJghognB-Uk5Z4KfzWYjaiKeqOAkDHQowQXZwHCG06yYlAxaxdMtH_CfM1rqMDI0eN8aAjUc8YtaRxZtYOavVkgLA9v4d0IHco2dZ_NpvhyoPwPCv_SyzkXD7_DszSfN7sAjM5uJaRn3JiJnC3Ekcaavtd2LWatbiItXiOkBFYxmvVMQUF2fSpINna4yUAP6Q_A2j7OXBwBqsR8B15Gc_1ltKcrZz1gv--X1Ba54vRr2C-42P8X_v8_GfPbJ5YyzVy8Ib1bckMPN-Vp25GV90N-dcuQlHaqO3DtLErABqwxWEIs6OKcn-Ps-8H3zyyJxTsP6gNZzgb9RaodnwGl4g8A371nXTRT780GkEZJoXfE7lCeKvMjzm6LMb4vpBw" type="text/javascript">
#          </script>
#          <script type="text/javascript">
#           var _eStat_Whap_loaded = 0;
#          </script>
#          <script type="text/javascript">
#           var af_diapo_list = [];
#  var af_diapo_common = {};
#  var af_diapo_instances = {};
#          </script>
#          <script type="text/javascript">
#           af_diapo_list.push({"defaultTitle":"Tacos mexicains","current":0,"diapoSize":5,"forwardCallbackURL":null,"id":"af-diapo-desktop-0","isStory":0,"isOPS":0,"isRecipeDiapo":1,"nextPhotosCallbackURL":"\/reloaded\/api\/recipe\/recipe_picture?recipe_id=34389","photos":[[87658,"https:\/\/assets.afcdn.com\/recipe\/20190212\/87658_w600cxt0cyt0cxb6236cyb4154.jpg",600,400,"","https:\/\/assets.afcdn.com\/recipe\/20190212\/87658_s96cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg","vasiliybudarin \/ istock \/ Getty Images",1,null],[63182,"https:\/\/assets.afcdn.com\/recipe\/20140814\/63182_w600.jpg",276,414,"","https:\/\/assets.afcdn.com\/recipe\/20140814\/63182_s96cx900cy1350.jpg","Manina Hatzimichali",2,null],[58478,"https:\/\/assets.afcdn.com\/recipe\/20130309\/58478_w600.jpg",600,450,"","https:\/\/assets.afcdn.com\/recipe\/20130309\/58478_s96cx256cy192.jpg","",3,null],[103275,"https:\/\/assets.afcdn.com\/recipe\/20191201\/103275_w600cxt0cyt0cxb1824cyb2432.jpg",311,414,"","https:\/\/assets.afcdn.com\/recipe\/20191201\/103275_s96cx912cy1216cxt0cyt0cxb1824cyb2432.jpg","",4,null],[109281,"https:\/\/assets.afcdn.com\/recipe\/20200327\/109281_w600cxt0cyt0cxb1319cyb1746.jpeg",313,414,"","https:\/\/assets.afcdn.com\/recipe\/20200327\/109281_s96cx659cy873cxt0cyt0cxb1319cyb1746.jpeg","",5,null]],"sButtons":"<div id=\"af-socials-btn-diapo-desktop-0\" class=\"af-social-share-v2 diapoDesktop open\"><\/div>","sButtonsId":"af-socials-btn-diapo-desktop-0","seeAlsoTitle":"you might also like","useModalForAlert":true,"alert":{"url":"\/reloaded\/api\/recipe\/reportpicture","label":"alerter"}})
#          </script>
#          <script type="text/javascript">
#           var aufAdtechParams = {};
#
#  var sas_formatIds = '';
#  var sas_pageId = 19216;
#  var sas_dfpPageId = 'recipes';
#  var sas_target = '';
#          </script>
#          <script type="text/javascript">
#           window.afSession = window.afSession || new AufSession();
#          </script>
#          <script type="text/javascript">
#           window.afLogger = window.afLogger || new Aflog.Logger();
#  af_addEvent(window, 'beforeunload', function() {
#  afLogger.sendLogsToBigQuery();
#  }, false);
#          </script>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.marmiton.org","name":"Accueil"}},{"@type":"ListItem","position":2,"item":{"@id":"/recettes/","name":"Recettes"}},{"@type":"ListItem","position":3,"item":{"@id":"/recettes/index/categorie/plat-principal/","name":"plat principal"}},{"@type":"ListItem","position":4,"item":{"@id":"/recettes/index/categorie/plat-unique/","name":"plat unique"}},{"@type":"ListItem","position":5,"item":{"@id":"/recettes/index/categorie/plats-mexicains/","name":"plats mexicains"}}]}
#          </script>
#          <script type="text/javascript">
#           var Mrtn = Mrtn || {}; Mrtn.recipesData = {"user_email":"","recipes":[{"name":"Tacos mexicains","url":"https:\/\/www.marmiton.org\/recettes\/recette_tacos-mexicains_34389.aspx","picture_url":"https:\/\/assets.afcdn.com\/recipe\/20190212\/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg","nb_pers":4,"note":4.5999999999999996,"ingredients":[{"name":"tortilla","qty":8,"unit":""},{"name":"oignon blanc","qty":1,"unit":""},{"name":"tomate","qty":2,"unit":""},{"name":"coulis de tomate","qty":1,"unit":"verre"},{"name":"boeuf hach\u00e9","qty":250,"unit":"g"},{"name":"haricots rouges","qty":1,"unit":"petite bo\u00eete"},{"name":"poivron vert","qty":0.5,"unit":""},{"name":"laitue","qty":8,"unit":"feuille"},{"name":"cumin en poudre","qty":"","unit":""},{"name":"poivre","qty":"","unit":""},{"name":"sel","qty":"","unit":""},{"name":"tabasco","qty":"","unit":""}]}]};
#          </script>
#          <script type="text/javascript">
#           var Mrtn = Mrtn || {};
#  Mrtn.RECIPE = {id : 34389,
#  tagGAPrevNext : "RecipesFromSimilar" };
#  Mrtn.store = Mrtn.store || {};
#  Mrtn.RECAPTCHA_KEY = { sitekey : "6LdGkywUAAAAAOpGYA0LZwMzNsX-JVJ96JfBz6FL"};
#  Mrtn.blurredPicture = { src : "https://assets.afcdn.com/recipe/20100101/recipe_default_img_blurred_8.jpg" };
#          </script>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org","@type":"Recipe","name":"Tacos mexicains","recipeCategory":"plats mexicains","image":"https://assets.afcdn.com/recipe/20190212/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg","datePublished":"2006-10-23T11:43:00+02:00","prepTime":"PT30M","cookTime":"PT25M","totalTime":"PT55M","recipeYield":"4 personnes","recipeIngredient":["8 tortillas pour tacos (achet\u00e9s, ou recette sur le site Marmiton)","1 oignon blanc","2 tomates","1 verre de coulis de tomate (10 cl)","250 g de boeuf hach\u00e9","1 petite bo\u00eete de haricots rouges","1/2 poivron vert","8 feuilles de laitue","cumin en poudre","poivre","sel","tabasco (facultatif)"],"recipeInstructions":[{"@type":"HowToStep","text":"A la po\u00eale, faire dorer l'oignon \u00e9minc\u00e9 dans un peu d'huile d'olive. "},{"@type":"HowToStep","text":"Rajouter la viande, assaisonner et laisser cuire 5 min. "},{"@type":"HowToStep","text":"Laver les feuilles de laitue. "},{"@type":"HowToStep","text":"Couper les tomates et le poivron en petits d\u00e9s. "},{"@type":"HowToStep","text":"Incorporer le tout \u00e0 la po\u00eal\u00e9e avec le coulis de tomate, et poursuivre la cuisson pendant 5 min. "},{"@type":"HowToStep","text":"Egoutter les haricots rouges et les ajouter 2 min avant la fin de cuisson. "},{"@type":"HowToStep","text":"Hors du feu, ajuster l'assaisonnement et saupoudrer g\u00e9n\u00e9reusement de cumin; on peut aussi rajouter quelques gouttes de Tabasco. "},{"@type":"HowToStep","text":"Garnir les tortillas de pr\u00e9paration et les refermer en les roulant comme des cr\u00eapes. Disposer 1 feuille de laitue sur chaque tacos avant de servir."}],"author":"noor_16706694","description":"tortilla, oignon blanc, tomate, coulis de tomate, boeuf hach\u00e9, haricots rouges, poivron vert, laitue, cumin en poudre, poivre, sel, tabasco","keywords":"Tacos mexicains, plats mexicains, tortilla, oignon blanc, tomate, coulis de tomate, boeuf hach\u00e9, haricots rouges, poivron vert, laitue, cumin en poudre, poivre, sel, tabasco,tr\u00e8s facile,bon march\u00e9","recipeCuisine":"","aggregateRating":{"@type":"AggregateRating","reviewCount":29,"ratingValue":4.5999999999999996,"worstRating":0,"bestRating":5},"video":{"@type":"VideoObject","name":"Tacos mexicains","description":"Tacos mexicains","thumbnailUrl":["https://assets.afcdn.com/video13/20161130/v528175_8142_18.jpg"],"contentUrl":"https://assets.afcdn.com/video13/20161130/v528175_8142_18_sd.mp4","embedUrl":"https://aufeminin.com/reloaded/embed/video/528175","uploadDate":"2016-11-29T23:53:00+01:00"}}
#          </script>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org","@type":"ItemList","url":"https://www.marmiton.org/recettes/recette_tacos-mexicains_34389.aspx","numberOfItems":10,"itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.marmiton.org/recettes/recette_tacos-mexicains_34389.aspx"},{"@type":"ListItem","position":2,"url":"https://www.marmiton.org/recettes/recette_french-tacos_349386.aspx"},{"@type":"ListItem","position":3,"url":"https://www.marmiton.org/recettes/recette_tortillas-pour-tacos_29730.aspx"},{"@type":"ListItem","position":4,"url":"https://www.marmiton.org/recettes/recette_poulet-a-la-mexicaine_220551.aspx"},{"@type":"ListItem","position":5,"url":"https://www.marmiton.org/recettes/recette_apero-mexicain_85499.aspx"},{"@type":"ListItem","position":6,"url":"https://www.marmiton.org/recettes/recette_veloute-de-mais-a-la-mexicaine_53614.aspx"},{"@type":"ListItem","position":7,"url":"https://www.marmiton.org/recettes/recette_omelette-mexicaine_68226.aspx"},{"@type":"ListItem","position":8,"url":"https://www.marmiton.org/recettes/recette_pizza-mexicaine_56479.aspx"},{"@type":"ListItem","position":9,"url":"https://www.marmiton.org/recettes/recette_pate-mexicain_10610.aspx"},{"@type":"ListItem","position":10,"url":"https://www.marmiton.org/recettes/recette_riz-a-la-mexicaine-express-facile_36830.aspx"}]}
#          </script>
#          <script type="text/javascript">
#           af_translations = {};
# af_translations.sButtonsShareText = "Partager sur #socialNetworkName#";
# af_translations.sTooltipsShareText = "Partage désactivé";
#          </script>
#          <script type="text/javascript">
#           // add global random value from 1 to 100
#  var afGlobalRandomValue = Math.floor(Math.random() * 100) + 1;
#  // push see also event
#  var afSeeAlsoEnabled = afGlobalRandomValue % (100/10) == 0;
#  // To make other subdomains able to contact this page
#  if (document.domain && typeof(sas_ddotpos) == 'undefined') {
#  sas_ddotpos = document.domain.indexOf('.');
#  if (sas_ddotpos > 0) document.domain = document.domain.substr(sas_ddotpos + 1);
#  }
#          </script>
#          <script type="text/javascript">
#           var m_isConnected = (af_getCookie('MARMICOOK') != '') && (af_getCookie('MARMIGUID') != '') && (af_getCookie('UserConnectedCookie') != '') ? 1 : 0;
#  var m_userInfo = {
#  'hashedUserId': (m_isConnected && Mrtn && Mrtn.cookbooks && Mrtn.cookbooks.cookbooks && Mrtn.cookbooks.cookbooks.UserInfos && Mrtn.cookbooks.cookbooks.UserInfos.HashedUserId) ? Mrtn.cookbooks.cookbooks.UserInfos.HashedUserId : '',
#  'newsletter': (m_isConnected && Mrtn && Mrtn.cookbooks && Mrtn.cookbooks.cookbooks && Mrtn.cookbooks.cookbooks.UserInfos && Mrtn.cookbooks.cookbooks.UserInfos.Newsletter) ? Mrtn.cookbooks.cookbooks.UserInfos.Newsletter : ''
#  }
#          </script>
#          <script type="text/javascript">
#           if (location.hash && location.hash.toLowerCase().substr(0, 5) == '#via=') {
#  var via = location.hash.substr(5).split('::');
#  if (via.length == 3) document.location.hash = 'utm_campaign='+via[0]+'&utm_medium='+via[1]+'&utm_source='+via[2];
#  };
#          </script>
#          <script type="text/javascript">
#           var af_winSize = af_windowSize();
#          </script>
#          <script type="text/javascript">
#           var af_consentInternetTargeting = true; // @TODO to remove, no longer reliable
#  var af_consentAdsTargeting = true; // @TODO to remove, no longer reliable
#          </script>
#          <script type="text/javascript">
#           m_dataLayer = [{
#  'contentInfo': {
#  'recipeIngredients': 'tortilla,oignon-blanc,tomate,coulis-de-tomate,boeuf-hache,haricots-rouges,poivron-vert,laitue,cumin-en-poudre,poivre,sel,tabasco',
#  'recipeIngredientsIds': '1071,1142,1057,0292,1758,0510,7371,0580,1558,0835,0990,1237',
#  'recipeType': 'entree',
#  'recipeDifficulty': 'tresfacile',
#  'recipeCost': 'bonmarche',
#  'recipeBrand': 'none',
#  'recipeSelection': 'none',
#  'recipePreparationTime': 30,
#  'recipeCookingTime': 25,
#  'recipeServings': 4,
#  'recipeTitle': 'Tacos mexicains',
#  'recipeId': 34389
#  },
#  'vuid': af_guid(),
#  'siteInfo': {
#  'sid': 13,
#  'platform': 'marmiton',
#  'uaid': 'UA-1901803-10',
#  'optimizeId': '0',
#  'lang': 'fr',
#  'isMobile': 0,
#  'gemkey': 'none',
#  'applicationType': 'default'
#  },
#  'pageInfo': {
#  'trackPageview': 1,
#  'rid': 0,
#  'srid': 0,
#  'sec': 'none / none',
#  'version' : 'new',
#  'contentType': 'recette',
#  'ops': 'none',
#  'ops_uaid': 'none',
#  'section': 'none',
#  'subsection': 'none',
#  'thematic': '',
#  'tag': '',
#  'tags': 'none',
#  'category': ''
#
#  },
#  'userInfo': {
#  'du': 'none',
#  'logged': m_isConnected,
#  'device': 'desktop',
#  'hashedUserId': m_userInfo.hashedUserId,
#  'referer': document.referrer,
#  'userAgent': navigator.userAgent,
#  'adblocker': 'N/A',
#  'segment': afSession.getSegment(),
#  'screenResolution': af_winSize.w + 'x' + af_winSize.h,
#  'adb': '',
#  'newsletters': m_userInfo.newsletter,
#  'consentInternetTargeting': (af_consentInternetTargeting ? 1 : 0),
#  'consentAdsTargeting': (af_consentAdsTargeting ? 1 : 0),
#  'isSubToMainNL': (af_getCookie('issubmainnl')=='1' ? 1 : 0),
#  'signupType': af_getCookie('signuptype')
#  },
#  'campaignInfo': {
#  'utmSource': afSession.getUtmSource(),
#  'utmMedium': afSession.getUtmMedium(),
#  'utmCampaign': afSession.getUtmCampaign(),
#  'paid' : afSession.isPaid() ? 1 : 0
#  }}];
#          </script>
#          <script type="text/javascript">
#           var af_dataLayer = m_dataLayer;
#          </script>
#          <script type="text/javascript">
#           unify_dataSlayer = [{"page":{"urlBO":"Marmiton\/recettes\/plat-principal\/plat-unique\/plats-mexicains\/tacos-mexicains","level3":"plat-principal","level4":"plat-unique","level5":"plats-mexicains","level6":"tacos-mexicains","recipeDiets":"sans lactose","section":"none","subSection":"none","mainTag":"none","sectionId":0,"subSectionId":0,"trackPageview":1}},{"content":{"preparationTime":30,"cookingTime":25,"servings":4,"recipeRating":4.5999999999999996,"numberOfComments":29,"recipeTags":"entree,plat-unique,plats-mexicains","id":34389,"author":"noor_16706694","recipeType":"entree","recipeDifficulty":"tresfacile","recipeCost":"bonmarche","recipeSelection":"none","recipeIngredients":"tortilla,oignon-blanc,tomate,coulis-de-tomate,boeuf-hache,haricots-rouges,poivron-vert,laitue,cumin-en-poudre,poivre,sel,tabasco","recipeIngredientsIds":"1071,1142,1057,0292,1758,0510,7371,0580,1558,0835,0990,1237","label":"Tacos mexicains","type":"recette","dyninfeedcount":0}},{"site":{"platform":"marmiton","lang":"fr","sid":13,"environment":"production"}},{"user":{"id":m_userInfo.hashedUserId,"dom":"none","device":"desktop","screenResolution":af_winSize.w + 'x' + af_winSize.h,"referer":document.referrer,"segment":afSession.getSegment(),"adBlocker":"N\/A","isMobile":0,"userAgent":navigator.userAgent,"isLoggedIn":m_isConnected,"paid":afSession.isPaid() ? 1 : 0}},{"ops":{"name":"none","brand":"none","uaid":"none"}},{"utm":{"campaign":afSession.getUtmCampaign(),"medium":afSession.getUtmMedium(),"source":afSession.getUtmSource()}}]
#          </script>
#          <script type="text/javascript">
#           PubSub.subscribeOnce('ad.block.detect', function(msg, data) {
#  m_dataLayer[0].userInfo.adblocker = data.status ? 1 : 0;
#  unify_dataSlayer.push({user: {adBlocker: data.status ? 1 : 0}});
#  PubSub.publish('datalayer.ready', { datalayer: m_dataLayer[0] });
#  });
#          </script>
#          <script type="text/javascript">
#           afLogger.setDataLayer(m_dataLayer[0]);
#          </script>
#          <script type="text/javascript">
#           sas_target = (window.sas_target ? sas_target : '') + ';rid=00034389;titleword=tacos;titleword=mexicains;left-column=1;dt=entree;cout=bonmarche;d=veryeasy;ptime=medium;ctime=medium;p=salty;p=pork-free;recipecategory=0157;recipecategory=0114;recipecategory=0563;contenttype=recette;site=13s;version=desktop;platform=desktop;';
#          </script>
#          <script type="text/javascript">
#           aufAdtechParams = {"exclusivesAdsFormats":null,"formatIds":"native_shopping,300_atf,native_recipe_center,300_mtf,300_mtf_2,300_btf,banner_atf,banner_btf,dhtml","pageId":"recipes","placeholders":{"300_atf":{"hasRefresh":true}}};
#          </script>
#          <script type="text/javascript">
#           if (Math.random() < 0.1) {
#  (function() {
#  function hsLogError(message, category, sampling) {
#  var d = message.split('').reverse().join('');
#  new Image().src = 'https://www.marmiton.org/reloaded/errpix.php?'
#  + 'd=' + encodeURIComponent(d)
#  + (sampling ? '&s=' + sampling : '')
#  + (category ? '&c=' + encodeURIComponent(category) : '');
#  if (window.console && console.error) console.error('JS Catchall: ' + message);
#  }
#
#  var af_JsElementBlocked = false;
#  var af_nbErrorsToReport = 10;
#  window.onerror = function(message, url, line, column, error) {
#  if (af_nbErrorsToReport-- < 0) return;
#
#  var category = 'JS - window.onerror';
#
#  if (typeof message === 'string') {
#  if (message.indexOf('Script error') !== -1) {
#  category += ' - external';
#  }
#
#  if (url && url.indexOf(document.domain) === -1) {
#  message += ' @ ' + url;
#  if (typeof line !== undefined) {
#  message += ':' + line;
#  }
#  if (typeof column !== undefined) {
#  message += ':' + column;
#  }
#  }
#  } else if (typeof message == 'object' && message.srcElement && message.target) {
#  if (message.srcElement == '[object HTMLScriptElement]' && message.target == '[object HTMLScriptElement]') {
#  message = 'Error loading script';
#  } else {
#  message = 'Event Error - target:' + message.target + ' srcElement:' + message.srcElement;
#  af_JsElementBlocked = true;
#  }
#  } else if (typeof message == 'object') {
#  message = 'MESSAGE_OBJECT: ' + message.constructor.name;
#  } else {
#  message = 'MESSAGE_NOSTRING: ' + typeof message;
#  }
#
#  hsLogError(message, category);
#
#  return true;
#  };
#
#  var af_taggingToReport = true;
#  function checkTagging() {
#  if (!af_taggingToReport) return;
#  af_taggingToReport = false;
#  if (window.top != window.self) return; // Iframe
#  if (af_JsElementBlocked) return; // Errors when loading page
#
#  if (!window.af_dataLayer) {
#  hsLogError('GTM data layer missing', 'GTM', 1);
#  }
#  if (!window.af_ua_trackEvent) {
#  hsLogError('UA track event function missing', 'GTM', 1);
#  }
#  }
#
#  if (window.addEventListener) {
#  window.addEventListener('load', checkTagging, false);
#  } else if (window.attachEvent) {
#  window.attachEvent('onload', checkTagging);
#  }
#  })();
#  }
#          </script>
#          <!-- https://www.marmiton.org/reloaded/esi/ads?device=desktop&domuser=&issomtag=false&keywords=&source=organic -->
#          <link href="https://sac.ayads.co" rel="preconnect"/>
#          <link href="https://tlx.3lift.com" rel="preconnect"/>
#          <link href="https://a.teads.tv" rel="preconnect"/>
#          <link href="https://fastlane.rubiconproject.com" rel="preconnect"/>
#          <link href="https://aufeminin-g-d.openx.net" rel="preconnect"/>
#          <link href="https://ib.adnxs.com" rel="preconnect"/>
#          <link href="https://c.amazon-adsystem.com" rel="preconnect"/>
#          <link href="https://hb-api.omnitagjs.com" rel="preconnect"/>
#          <link href="https://cdn.jsdelivr.net" rel="preconnect"/>
#          <link href="https://adservice.google.com" rel="preconnect"/>
#          <link href="https://adservice.google.fr" rel="preconnect"/>
#          <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#          <link href="https://pubads.g.doubleclick.net" rel="preconnect"/>
#          <link href="https://www.googletagservices.com" rel="preconnect"/>
#          <link href="https://blog.marmiton.org" rel="preconnect"/>
#          <link href="https://www.marmiton.org" rel="preconnect"/>
#          <link href="https://static.afcdn.com" rel="preconnect"/>
#          <link href="https://assets.afcdn.com" rel="preconnect"/>
#          <script crossorigin="anonymous" src="https://static.afcdn.com/relmrtn/concat.js?PCM-lVJNb4MwDP01PS6CFO3jsENVqZd9qFqnXSsDhmYNMYpDW_79wpiokKADKUqe7ecXO87BuZIXy9VCbvxiSATUkLJIqDGrWKsCPZJR-PDoz9JirNLnLzQp2cauYk_yIBT3Iugcd6xMrtGREd98Zcd0ZrwCUah-HKrM77mmGPQ-oaIgs3dUDnAge6U89xJDoR0yKxqS9p11TbTO7S8eF-sntECKKBLRDPk1mUzlMxLewMDNgnSVK8Ot99NCcvTvvVUX1Dya43e0J7QN3vvA6s-elJBm5b_8XlG-ZYfGvWB9Jpvy8JycSo71mvSN6LTb5nC3YEFruExjbyipeBr1AzOLfJhGfgenTrhKJ2rvjmr8P7fD7P6wkIEMgkgugycZ_gA" type="text/javascript">
#          </script>
#          <script type="text/javascript">
#           window.afSession = window.afSession || new AufSession();
#          </script>
#          <script type="text/javascript">
#           window.afLogger = window.afLogger || new Aflog.Logger();
#  af_addEvent(window, 'beforeunload', function() {
#  afLogger.sendLogsToBigQuery();
#  }, false);
#          </script>
#          <script type="text/javascript">
#           window.aufAdtechParams = window.aufAdtechParams || {};
#  aufAdtechParams.domUser = '';
#  aufAdtechParams.isMobile = false;
#  aufAdtechParams.target = window.sas_target || '';
#  aufAdtechParams.adxAdjustedCpms = {"marmiton\/organic\/homepage\/native_block_right":{"ad_unit_id":21725234505,"ad_unit_path":"marmiton\/organic\/homepage\/native_block_right","cpm_1_day":0.13565209441215978,"cpm_7_days":null},"marmiton\/organic\/others\/banner_btf":{"ad_unit_id":21727616785,"ad_unit_path":"marmiton\/organic\/others\/banner_btf","cpm_1_day":0.42836285733039609,"cpm_7_days":0.4988434572239136},"marmiton\/organic\/homepage\/native_block_left":{"ad_unit_id":21725174096,"ad_unit_path":"marmiton\/organic\/homepage\/native_block_left","cpm_1_day":0.10648332100146447,"cpm_7_days":0.32497528335561376},"marmiton\/video\/preroll_BTF":{"ad_unit_id":21665742705,"ad_unit_path":"marmiton\/video\/preroll_BTF","cpm_1_day":8.2122877677204116,"cpm_7_days":7.1796863027425601},"marmiton\/organic\/recipes\/native_recipe_center":{"ad_unit_id":21734545204,"ad_unit_path":"marmiton\/organic\/recipes\/native_recipe_center","cpm_1_day":0.41692716062379531,"cpm_7_days":0.39440598606197019},"marmiton\/organic\/recipes\/banner_atf":{"ad_unit_id":21727444506,"ad_unit_path":"marmiton\/organic\/recipes\/banner_atf","cpm_1_day":0.36918460403162651,"cpm_7_days":0.36246389340675622},"marmiton\/organic\/others\/300_btf":{"ad_unit_id":21734232959,"ad_unit_path":"marmiton\/organic\/others\/300_btf","cpm_1_day":0.3186628519857751,"cpm_7_days":0.36917392031996749},"marmiton\/organic\/search\/300_btf":{"ad_unit_id":21734235404,"ad_unit_path":"marmiton\/organic\/search\/300_btf","cpm_1_day":0.25768843002689928,"cpm_7_days":0.2575269101274687},"marmiton\/organic\/recipes\/300_atf":{"ad_unit_id":21734240033,"ad_unit_path":"marmiton\/organic\/recipes\/300_atf","cpm_1_day":1.0904712983781237,"cpm_7_days":0.92868150431874974},"marmiton\/organic\/search\/banner_atf":{"ad_unit_id":21727444338,"ad_unit_path":"marmiton\/organic\/search\/banner_atf","cpm_1_day":0.49126037698283065,"cpm_7_days":0.50016139322670949},"marmiton\/organic\/others\/dhtml":{"ad_unit_id":21733566912,"ad_unit_path":"marmiton\/organic\/others\/dhtml","cpm_1_day":5.5806402825752226,"cpm_7_days":6.8643245734731808},"marmiton\/organic\/search\/300_atf":{"ad_unit_id":21734541475,"ad_unit_path":"marmiton\/organic\/search\/300_atf","cpm_1_day":0.8293506149284936,"cpm_7_days":0.69270597096948949},"marmiton\/organic\/homepage\/banner_atf":{"ad_unit_id":21725394400,"ad_unit_path":"marmiton\/organic\/homepage\/banner_atf","cpm_1_day":0.37394418131867208,"cpm_7_days":0.38966194285474659},"marmiton\/organic\/recipes\/300_mtf_2":{"ad_unit_id":21749712533,"ad_unit_path":"marmiton\/organic\/recipes\/300_mtf_2","cpm_1_day":1.6267090751745934,"cpm_7_days":0.26881808141597513},"marmiton\/organic\/expert_club\/300_diapodynamic":{"ad_unit_id":21749834646,"ad_unit_path":"marmiton\/organic\/expert_club\/300_diapodynamic","cpm_1_day":0.29991109308810837,"cpm_7_days":0.54960409111416841},"marmiton\/organic\/expert_club\/banner_atf":{"ad_unit_id":21727606120,"ad_unit_path":"marmiton\/organic\/expert_club\/banner_atf","cpm_1_day":1.5665744047224375,"cpm_7_days":2.3995358486173983},"marmiton\/organic\/others\/dyninfeed":{"ad_unit_id":21929114326,"ad_unit_path":"marmiton\/organic\/others\/dyninfeed","cpm_1_day":0.59253083168880671,"cpm_7_days":0.5198280053886184},"marmiton\/organic\/recipes\/banner_mtf":{"ad_unit_id":21749840757,"ad_unit_path":"marmiton\/organic\/recipes\/banner_mtf","cpm_1_day":0.32451097653742378,"cpm_7_days":0.34212044019565147},"marmiton\/organic\/search\/banner_btf":{"ad_unit_id":21727444377,"ad_unit_path":"marmiton\/organic\/search\/banner_btf","cpm_1_day":0.41205198054722242,"cpm_7_days":0.43398949013917748},"marmiton\/video\/preroll_MTF_seealso":{"ad_unit_id":21665741655,"ad_unit_path":"marmiton\/video\/preroll_MTF_seealso","cpm_1_day":9.7240624120272763,"cpm_7_days":7.7771130410182234},"marmiton\/organic\/expert_club\/300_atf":{"ad_unit_id":21734540788,"ad_unit_path":"marmiton\/organic\/expert_club\/300_atf","cpm_1_day":1.2546290133281244,"cpm_7_days":2.370787946997285},"marmiton\/organic\/ ...
#
#  if (!aufAdtechParams.formatIds) {
#  aufAdtechParams.formatIds = window.sas_formatIds || '';
#  } else if (!window.sas_formatIds) {
#  sas_formatIds = aufAdtechParams.formatIds;
#  }
#          </script>
#          <script type="text/javascript">
#           aufAdtechParams.adUnitPath = '229683329/marmiton/organic';
#  aufAdtechParams.adUnitPathHbForced = '229683329/marmiton/content_marketing';
#  aufAdtechParams.formatMapping = {"banner_atf":{"id":"banner_atf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["1x1","728x90","800x250","970x250","980x250","1000x90","1000x250","1020x250","1800x1000"]},"banner_atf_small":{"id":"banner_atf_small","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1","728x90","1000x90"]},"banner_mtf":{"id":"banner_mtf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["1x1","728x90","800x250","970x250","990x90","1000x90","1000x250","1020x250"]},"banner_mtf_small":{"id":"banner_mtf_small","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["728x90"]},"banner_btf":{"id":"banner_btf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["1x1","728x90","950x90","970x90","990x90","1000x90"]},"300_atf":{"id":"300_atf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["120x600","160x600","300x250","300x600"]},"300_mtf":{"id":"300_mtf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1","300x250"]},"300_mtf_2":{"id":"300_mtf_2","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["300x250"]},"300_mtf_3":{"id":"300_mtf_3","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["300x250"]},"300_btf":{"id":"300_btf","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["300x250"]},"300_diapodynamic":{"id":"300_diapodynamic","hasLabel":false,"isAsync":true,"isCentered":true,"sizes":["120x600","160x600","300x250","300x600"]},"sitebar_left":{"id":"sitebar_left","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["120x600","160x600"]},"sitebar_right":{"id":"sitebar_right","hasLabel":false,"isAsync":false,"isCentered":false,"sizes":["120x600","160x600"]},"native_home_dynamic":{"id":"native_home_dynamic","hasLabel":false,"isAsync":false,"isCentered":false,"sizes":["fluid","1x1"]},"native_seealso_right":{"id":"native_seealso_right","hasLabel":false,"isAsync":false,"isCentered":false,"sizes":["fluid","1x1"]},"native_seealso_left":{"id":"native_seealso_left","hasLabel":true,"isAsync":false,"isCentered":false,"sizes":["fluid","1x1"]},"inread":{"id":"inread","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["1x1"]},"dhtml":{"id":"dhtml","hasLabel":false,"isAsync":false,"isCentered":false,"sizes":["1x1","320x480"]},"native_seealso":{"id":"native_seealso","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1"]},"native_recipe_center":{"id":"native_recipe_center","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1"]},"native_shopping":{"id":"native_shopping","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1","229x240"]},"native_block_left":{"id":"native_block_left","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1"]},"native_block_right":{"id":"native_block_right","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1"]},"300_newsletter":{"id":"300_newsletter","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["300x250"]},"native_article_center":{"id":"native_article_center","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","1x1"]},"dyninfeed":{"id":"dyninfeed","hasLabel":false,"isAsync":false,"isCentered":true,"sizes":["fluid","300x250","1x1"]}};
#          </script>
#          <script type="text/javascript">
#           window.afAd = new AufAds.DFPAdserver(aufAdtechParams);
#  afAd.initQueue();
#          </script>
#          <script type="text/javascript">
#           (function() {
#  var s = document.createElement('script');
#  s.type = 'text/javascript';
#  s.async = true;
#  s.src = 'https://boot.pubstack.io/v1/tag/bff46cdb-3c4d-4c5c-beb8-5f215129fff5';
#  document.getElementsByTagName('head')[0].appendChild(s);
#  })();
#          </script>
#          <script type="text/javascript">
#           if (!window.aufHBDisabled) {
#  if (window.aufbidjs) {
#  afLogger.logError('HB already initialized', 'HB');
#  } else if (!window.AufPrebid) {
#  afLogger.logError('AufPrebid library not defined', 'HB');
#  } else {
#  window.aufbidjsParams = {
#  data: {"formats":{"300_atf":{"asyncOnly":false,"position":"ATF"},"300_diapodynamic":{"asyncOnly":true,"position":"ATF"},"300_mtf_2":{"asyncOnly":false,"position":"MTF"},"dyninfeed":{"asyncOnly":false,"position":"MTF"},"300_btf":{"asyncOnly":false,"position":"BTF"},"300_mtf":{"asyncOnly":true,"position":"MTF"},"banner_atf":{"asyncOnly":false,"position":"ATF"},"banner_btf":{"asyncOnly":false,"position":"BTF"},"sitebar_left":{"asyncOnly":false,"position":"ATF"},"300_mtf_3":{"asyncOnly":false,"position":"MTF"},"banner_mtf":{"asyncOnly":false,"position":"MTF"},"sitebar_right":{"asyncOnly":false,"position":"ATF"}},"accounts":[{"name":"AUF - AdYouLike","online_desktop":1,"online_mobile":1,"aliasBidder":"","bidder":"adyoulike","accountId":"","siteId":null,"currency":"USD","deal_commission":10,"open_commission":10,"adjustment":0,"grossRevenue":1,"placements":{"300_atf":[{"tag":"116a292b9204bec02e0f17407061eb73","size":"300x250"},{"tag":"71475320f251bd5294fc2f1429940e4b","size":"300x600"}],"300_diapodynamic":[{"tag":"f1ee3f3d2e781600e710e3ecd0ff609c","size":"300x600"},{"tag":"f727e3fe4cd6a91f8ab5b304f2a5c64a","size":"300x250"}],"300_mtf_2":[{"tag":"7c0e10880ca28cfb9497478f8b9c6921","size":"300x250"}],"dyninfeed":[{"tag":"54911187e9b21505fe48b7d162c786f8","size":"300x250"}]}},{"name":"AUF - Amazon","online_desktop":1,"online_mobile":1,"aliasBidder":"","bidder":"amazon","accountId":"3357","siteId":null,"currency":"USD","deal_commission":0,"open_commission":0,"adjustment":0,"grossRevenue":0,"placements":{"300_atf":[{"tag":"1","size":"160x600,300x600,300x250"}],"300_btf":[{"tag":"1","size":"300x250"}],"300_diapodynamic":[{"tag":"1","size":"160x600,300x600"},{"tag":"1","size":"300x250"}],"300_mtf":[{"tag":"1","size":"300x250"}],"banner_atf":[{"tag":"1","size":"728x90"},{"tag":"1","size":"970x250"}],"banner_btf":[{"tag":"1","size":"728x90"}],"dyninfeed":[{"tag":"1","size":"300x250"}],"sitebar_left":[{"tag":"1","size":"160x600"}]}},{"name":"AUF - AppNexus","online_desktop":1,"online_mobile":1,"aliasBidder":"","bidder":"appnexus","accountId":"7695","siteId":null,"currency":"USD","deal_commission":0,"open_commission":0,"adjustment":1,"grossRevenue":0,"placements":{"300_atf":[{"tag":"11317811","size":"300x600,300x250,160x600,120x600"}],"300_btf":[{"tag":"11317815","size":"300x250"}],"300_diapodynamic":[{"tag":"12331751","size":"300x250"},{"tag":"12331751","size":"300x600,160x600,120x600"}],"300_mtf":[{"tag":"11317813","size":"300x250"}],"300_mtf_2":[{"tag":"18281834","size":"1x1","context":"outstream"}],"banner_atf":[{"tag":"11317810","size":"728x90"},{"tag":"11317810","size":"1800x1000"},{"tag":"11317810","size":"970x250,1000x90"}],"banner_btf":[{"tag":"12331756","size":"1000x90,728x90"}],"dyninfeed":[{"tag":"18593380","size":"300x250"}],"sitebar_left":[{"tag":"12148305","size":"120x600,160x600"}]}},{"name":"AUF - Criteo","online_desktop":1,"online_mobile":1,"aliasBidder":"","bidder":"criteo","accountId":"6710","siteId":null,"currency":"EUR","deal_commission":0,"open_commission":0,"adjustment":0,"grossRevenue":0,"placements":{"300_atf":[{"tag":"846863","size":"300x600"}],"300_btf":[{"tag":"300x250","size":"728x90"}],"300_diapodynamic":[{"tag":"846860","size":"300x600"}],"banner_atf":[{"tag":"846866","size":"970x250"}],"banner_btf":[{"tag":"846864","size":"728x90"}],"dyninfeed":[{"tag":"1501826","size":"300x250"}]}},{"name":"AUF - IAS","online_desktop":1,"online_mobile":1,"aliasBidder":"","bidder":"ias","accountId":"929475","siteId":null,"currency":"USD","deal_commission":0,"open_commission":0,"adjustment":0,"grossRevenue":0,"placements":{"300_atf":[{"tag":"300_atf","size":"300x250"}],"300_btf":[{"tag":"300_btf","size":"300x250"}],"300_diapodynamic":[{"tag":"300_diapodynamic_desktop","size":"300x250"}],"300_mtf":[{"tag":"300_mtf","size":"300x250"}],"300_mtf_2":[{"tag":"300_mtf_2","size":"300x250"}],"300_mtf_3":[{"tag":"300_mtf_3","size":"300x250"}],"banner_atf":[{"tag":"banner_atf","size":"1x1"}],"banner_btf":[{"tag":"banner_btf_desktop","size": ...
#  isMobile: false,
#  currenciesRates: {"ARS":0.015170599999999999,"CAD":0.65677099999999999,"GBP":1.14679,"MXN":0.037962500000000003,"USD":0.92833299999999996},
#  floorPrices: {"300_atf_300x250":0.34999999999999998,"banner_atf_970x250":1,"300_atf_300x600":0.34999999999999998,"banner_atf_728x90":0.050000000000000003,"banner_atf":0.050000000000000003,"300_btf":0.050000000000000003,"300_atf_160x600":0.34999999999999998,"300_diapodynamic":0.40000000000000002,"banner_btf":0.050000000000000003,"banner_atf_1800x1000":3,"banner_atf_1000x90":0.050000000000000003,"300_atf":0.34999999999999998,"300_atf_120x600":0.34999999999999998,"300_mtf":0.050000000000000003,"300_mtf_2":0.050000000000000003,"banner_atf_1x1":3,"dyninfeed":0.10000000000000001},
#  geoLoc: '---'
#  };
#  window.aufbidjs = AufPrebid.Manager;
#  window.aufbidjs.init(aufbidjsParams);
#  }
#  }
#
#  if (!window.AufTrackingPixels) {
#  afLogger.logError('AufTrackingPixels library not defined', 'ads');
#  } else {
#  AufTrackingPixels.init({
#  isMobile: false,
#  });
#  }
#          </script>
#          <script type="text/javascript">
#           if (Math.random() < 0.1) {
#  (function() {
#  function hsLogError(message, category, sampling) {
#  var d = message.split('').reverse().join('');
#  new Image().src = 'https://www.marmiton.org/reloaded/errpix.php?'
#  + 'd=' + encodeURIComponent(d)
#  + (sampling ? '&s=' + sampling : '')
#  + (category ? '&c=' + encodeURIComponent(category) : '');
#  if (window.console && console.error) console.error('JS Catchall: ' + message);
#  }
#
#  var af_JsElementBlocked = false;
#  var af_nbErrorsToReport = 10;
#  window.onerror = function(message, url, line, column, error) {
#  if (af_nbErrorsToReport-- < 0) return;
#
#  var category = 'JS - window.onerror';
#
#  if (typeof message === 'string') {
#  if (message.indexOf('Script error') !== -1) {
#  category += ' - external';
#  }
#
#  if (url && url.indexOf(document.domain) === -1) {
#  message += ' @ ' + url;
#  if (typeof line !== undefined) {
#  message += ':' + line;
#  }
#  if (typeof column !== undefined) {
#  message += ':' + column;
#  }
#  }
#  } else if (typeof message == 'object' && message.srcElement && message.target) {
#  if (message.srcElement == '[object HTMLScriptElement]' && message.target == '[object HTMLScriptElement]') {
#  message = 'Error loading script';
#  } else {
#  message = 'Event Error - target:' + message.target + ' srcElement:' + message.srcElement;
#  af_JsElementBlocked = true;
#  }
#  } else if (typeof message == 'object') {
#  message = 'MESSAGE_OBJECT: ' + message.constructor.name;
#  } else {
#  message = 'MESSAGE_NOSTRING: ' + typeof message;
#  }
#
#  hsLogError(message, category);
#
#  return true;
#  };
#
#  var af_taggingToReport = true;
#  function checkTagging() {
#  if (!af_taggingToReport) return;
#  af_taggingToReport = false;
#  if (window.top != window.self) return; // Iframe
#  if (af_JsElementBlocked) return; // Errors when loading page
#
#  if (!window.af_dataLayer) {
#  hsLogError('GTM data layer missing', 'GTM', 1);
#  }
#  if (!window.af_ua_trackEvent) {
#  hsLogError('UA track event function missing', 'GTM', 1);
#  }
#  }
#
#  if (window.addEventListener) {
#  window.addEventListener('load', checkTagging, false);
#  } else if (window.attachEvent) {
#  window.attachEvent('onload', checkTagging);
#  }
#  })();
#  }
#          </script>
#          <link href="https://ad.doubleclick.net" rel="preconnect">
#           <link href="https://www.gstatic.com" rel="preconnect">
#            <link href="https://googleads.g.doubleclick.net" rel="preconnect">
#             <link href="https://pagead2.googlesyndication.com" rel="preconnect">
#              <link href="https://www.marmiton.org/recettes/recette_tacos-mexicains_34389.aspx" rel="canonical">
#               <link href="/rss/livres-a-devorer.aspx" rel="alternate" title="Livres à dévorer" type="application/rss+xml">
#                <link href="/rss/nouveaux-produits.aspx" rel="alternate" title="Nouveaux Produits" type="application/rss+xml">
#                 <link href="/rss/mots-gourmands.aspx" rel="alternate" title="Mots gourmands" type="application/rss+xml">
# ...
#          Politique de protection des données personnelles
#         </a>
#         ●
#         <a href="https://www.marmiton.org/aide/politique-de-protection-des-donnees-de-marmiton-s3007453.html">
#          Politique de confidentialité
#         </a>
#         ●
#         <a href="javascript:showCmpPreferencesPopup()">
#          Préférences cookies
#         </a>
#        </p>
#        <p>
#         Pour des milliers de cocktails :
#         <a href="http://www.1001cocktails.com">
#          1001cocktails.com
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script crossorigin="anonymous" src="https://static.afcdn.com/relmrtn/concat.js?PCM-hVNNa8MwDP01PSZk6S477FBSCoMVRlZ6HU6sJG5sK7OVlfz72XQtjet2kA89vSfJH9IeNEezyDdsbNy3lVgx-VWjUqjTg33dn_nD9whmuhgpx3pUoKkExqdUibl6lo2D7QmHiIA1nyTqfipQerZANaB2SR1liRlbMhK6nSMv_GAt7KYBHGOgFlfGYzZhEgwlCjmT_yiJVfaeRBnSSSWx7u8pCNQgGUECuhUaws3ViH3l3hXnW7-WiCsM0UjT3y-kTlW3oHAG4rISfgQcC2a4jfkeBW3QqIgrDPGns0OUJIY5iudeCzZggZruOcMw7rn1qacCGK_wphu0cxQKXV8Z4MIBW57v8MbngzqiwS6WK8e755iC60xK3bz4yfBFjh27WUaDSGDeRdsFKBR2bpjAXIw4fc4DbWsfK66QE6Z5lmfZc77MXvKnXw" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jquery$(function(){
#  window.af_disableHeaderShrinking = true;
#  var appAufHeader = new AufHeader();
#  appAufHeader.init({
#  searchPlaceholder: "Search"
#  });
#  });
#   </script>
#   <script type="text/javascript">
#    if (_eStat_Whap_loaded) { eStatWhap.serial('800000206973'); }
#   </script>
#   <script type="text/javascript">
#    function af_callAudienceTrackers() {
#  // NIELSEN
#  if (typeof NolTracker !== 'undefined') { trac.record().post(); } // IT
#  if (typeof _eStat_Whap_loaded !== 'undefined' && _eStat_Whap_loaded) { eStatWhap.send(); } // Others
#  }
#
#  (function() {
#  if (typeof window.__cmp !== 'undefined') {
#  window.didomiOnReady = window.didomiOnReady || [];
#  window.didomiOnReady.push(function addTrackersIfConsentGiven(Didomi) {
#  if(Didomi.getUserConsentStatusForPurpose("analytics") === true) {
#  af_callAudienceTrackers();
#  }
#  });
#  } else {
#  af_callAudienceTrackers();
#  };
#  }());
#   </script>
#   <script type="text/javascript">
#    af_addEvent(document, 'click', ga_trackOutboundLink, false);
#   </script>
#   <script type="text/javascript">
#    var appSButtonsV2 = appSButtonsV2 || {};
#
# jquery$(function() {
#  var sBtnInfos = {
#  isMobile: false,
#  shareImg: "https:\/\/assets.afcdn.com\/recipe\/20190212\/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg",
#  shareProviders: ["facebook","twitter","pinterest","mail"],
#  shareTitle: "Tacos mexicains",
#  shareUrl: "https:\/\/www.marmiton.org\/recettes\/recette_tacos-mexicains_34389.aspx",
#  initOpen: true,
#  providers: {
#  facebook: {
#  pageURL: "https:\/\/www.facebook.com\/marmiton",
#  showLikeButton: null,
#  url: " https:\/\/www.facebook.com\/dialog\/feed?app_id=179380945463734&display=popup&redirect_uri=https:\/\/www.marmiton.org\/reloaded\/followUs\/facebook&link=",
#  urlFollowUs: "https:\/\/www.marmiton.org\/reloaded\/followUs\/facebook"
#  },
#  pinterest: {
#  urlFollowUs: "https:\/\/www.marmiton.org\/reloaded\/followUs\/pinterest",
#  shareImg:"https:\/\/assets.afcdn.com\/recipe\/20190212\/87658_w1024h768c1cx1663cy2227cxt0cyt0cxb6236cyb4154.jpg"
#  }
#  }
#  };
#  appSButtonsV2["af-socials-btn-1587728954"] = new AufSButtonsV2();
#  appSButtonsV2["af-socials-btn-1587728954"].init("af-socials-btn-1587728954", "album", sBtnInfos);
# });
#   </script>
#   <script type="text/javascript">
#    var appBlock = new MrtnBlock();
#  appBlock.init({
#  blockClassName: "recipe-preparation__list",
#  actionGA: "PreparationBlock - Display - Sampling 10%",
#  sampling: 10
#  });
#   </script>
#   <script type="text/javascript">
#    var mrtnRecipeDefs=[];
#   </script>
#   <script type="text/javascript">
#    var ingredientsGroups = new Mrtn.IngredientsGroups();
#  ingredientsGroups.updateQts();
#
#  var appIngredientsRecipe = new Mrtn.IngredientsRecipe();
#  appIngredientsRecipe.init({
#  ingredientsGroups: [{"id":22396,"name":null,"position":1,"ingredient_group_items":[{"id":731575,"ingredient":{"id":1071,"story_id":null,"name":"tortilla","plural":"tortillas","token":"tortilla","picture":{"id":67727,"origin_id":1071,"type_id":3,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20170607\/67727_origin.jpg","width":700,"height":700,"origin_width":700,"origin_height":700,"center_x":350,"center_y":350,"crop_x_top":null,"crop_y_top":null,"crop_x_bottom":null,"crop_y_bottom":null,"position":1,"alt":"","credits":"","creation_date":"2017-06-07T17:27:17+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20170607","extension":"jpg"},"is_prog":false,"modification_date":"2019-05-21T17:23:12+02:00","album_id":null,"selection_id":null,"ingredient_infos":null,"url_pinterest":null,"is_gluten":true,"is_pork":false,"is_vegan":true,"is_vegetarian":true,"is_fish":false,"is_nuts":false,"is_egg":false,"is_lactose":false,"url":null,"brand_id":null,"season_status":1},"quantity":8,"position":1,"complement":"pour tacos (achet\u00e9s, ou recette sur le site Marmiton)","complement_plural":"pour tacos (achet\u00e9s, ou recette sur le site Marmiton)"},{"id":731576,"ingredient":{"id":1142,"story_id":null,"name":"oignon blanc","plural":"oignons blancs","token":"oignon-blanc","picture":{"id":67525,"origin_id":1142,"type_id":3,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20170607\/67525_origin.jpg","width":700,"height":700,"origin_width":700,"origin_height":700,"center_x":350,"center_y":350,"crop_x_top":null,"crop_y_top":null,"crop_x_bottom":null,"crop_y_bottom":null,"position":1,"alt":"","credits":"","creation_date":"2017-06-07T17:27:17+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20170607","extension":"jpg"},"is_prog":false,"modification_date":"2020-03-30T03:03:53+02:00","album_id":null,"selection_id":null,"ingredient_infos":null,"url_pinterest":null,"is_gluten":false,"is_pork":false,"is_vegan":true,"is_vegetarian":true,"is_fish":false,"is_nuts":false,"is_egg":false,"is_lactose":false,"url":null,"brand_id":null,"season_status":3},"quantity":1,"position":2,"complement":null,"complement_plural":null},{"id":731577,"ingredient":{"id":1057,"story_id":null,"name":"tomate","plural":"tomates","token":"tomate","picture":{"id":67459,"origin_id":1057,"type_id":3,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20170607\/67459_origin.jpg","width":700,"height":700,"origin_width":700,"origin_height":700,"center_x":350,"center_y":350,"crop_x_top":null,"crop_y_top":null,"crop_x_bottom":null,"crop_y_bottom":null,"position":1,"alt":"","credits":"","creation_date":"2017-06-07T17:27:17+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20170607","extension":"jpg"},"is_prog":false,"modification_date":"2019-10-07T07:04:12+02:00","album_id":null,"selection_id":null,"ingredient_infos":{"id":25,"season":"\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tJ<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tF<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tM<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tA<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tM<\/div>\n\t\t\t\t<div class=\"mrtn-season-active\">\n\t\t\t\t\tJ<\/div>\n\t\t\t\t<div class=\"mrtn-season-active\">\n\t\t\t\t\tJ<\/div>\n\t\t\t\t<div class=\"mrtn-season-active\">\n\t\t\t\t\tA<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tS<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tO<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tN<\/div>\n\t\t\t\t<div class=\"mrtn-season-unactive\">\n\t\t\t\t\tD<\/div>\n\t\t\t\t","is_fruit":true,"is_vegetable":false,"infos_choose_buy":"Les tomates de pleine saison et m\u00fbres en ao\u00fbt-septembre sont douces et fruit\u00e9es.\n\nA l'achat, la tomate doit \u00eatre parfaitement lisse, sans t\u00e2che et de couleur franche. Les tomates vendues en grappe doivent \u00eatre bien attach\u00e9es \u00 ...
#  });
#   </script>
#   <script type="text/javascript">
#    var appBlock = new MrtnBlock();
#  appBlock.init({
#  blockClassName: "recipe-ingredients__list",
#  actionGA: "IngredientsBlock - Display - Sampling 10%",
#  sampling: 10
#  });
#   </script>
#   <script type="text/javascript">
#    var appUtensilsRecipe = new MrtnUtensilsRecipe();
#  appUtensilsRecipe.init({
#  utensils: [{"id":61,"name":"Po\u00eale","keyword":"po\u00eale","picture":{"id":109361,"origin_id":172,"type_id":6,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20200330\/109361_origincxt0cyt0cxb1498cyb748.jpg","width":1498,"height":748,"origin_width":1498,"origin_height":748,"center_x":749,"center_y":374,"crop_x_top":0,"crop_y_top":0,"crop_x_bottom":1498,"crop_y_bottom":748,"position":9999,"alt":"","credits":"","creation_date":"2020-03-30T18:16:07+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20200330","extension":"jpg"},"is_prog":true,"quantity":1,"position":1,"utensil_name":"po\u00eale","text":"54,07\u20ac","stroke_text":null,"url":"https:\/\/www.amazon.fr\/Tefal-L6509205-Expertise-Aluminium-Induction\/dp\/B01CTWGQQS?tag=mt-u-61-21","brand_id":163,"brand_name":"Amazon"},{"id":55,"name":"pinceau","keyword":"pinceau","picture":{"id":99811,"origin_id":155,"type_id":6,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20191001\/99811_origincxt0cyt0cxb549cyb1500.jpg","width":549,"height":1500,"origin_width":549,"origin_height":1500,"center_x":274,"center_y":750,"crop_x_top":0,"crop_y_top":0,"crop_x_bottom":549,"crop_y_bottom":1500,"position":9999,"alt":"","credits":"","creation_date":"2019-10-01T15:52:41+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20191001","extension":"jpg"},"is_prog":true,"quantity":1,"position":2,"utensil_name":"pinceau","text":"8,95\u20ac","stroke_text":null,"url":"https:\/\/www.amazon.fr\/Kaiser-2055931-Pinceau-p%C3%A2tisserie-Set-Autre\/dp\/B003OQVDBC?tag=mt-u-55-21","brand_id":163,"brand_name":"Amazon"},{"id":17,"name":"couteau","keyword":"couteau","picture":{"id":82613,"origin_id":0,"type_id":6,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20181011\/82613_origincxt0cyt0cxb1500cyb1500.jpg","width":1500,"height":1500,"origin_width":1500,"origin_height":1500,"center_x":750,"center_y":750,"crop_x_top":0,"crop_y_top":0,"crop_x_bottom":1500,"crop_y_bottom":1500,"position":9999,"alt":"","credits":"","creation_date":"2018-10-11T12:05:53+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20181011","extension":"jpg"},"is_prog":true,"quantity":1,"position":3,"utensil_name":"couteau","text":"Top 3 couteaux : le guide ultime","stroke_text":"","url":"https:\/\/urlz.fr\/cipm","brand_id":122,"brand_name":"Marmiton"},{"id":240,"name":"Po\u00eale \u00e0 cr\u00eapes","keyword":"cr\u00eapes","picture":{"id":109590,"origin_id":0,"type_id":6,"url_origin":"https:\/\/assets.afcdn.com\/recipe\/20200410\/109590_origincxt0cyt0cxb2121cyb1414.jpg","width":2121,"height":1414,"origin_width":2121,"origin_height":1414,"center_x":1060,"center_y":707,"crop_x_top":0,"crop_y_top":0,"crop_x_bottom":2121,"crop_y_bottom":1414,"position":9999,"alt":"","credits":"","creation_date":"2020-04-10T17:34:45+02:00","authorId":null,"user":null,"author_name":null,"datestring":"20200410","extension":"jpg"},"is_prog":true,"quantity":1,"position":5,"utensil_name":"Po\u00eale \u00e0 cr\u00eapes","text":"17,99\u20ac","stroke_text":null,"url":"https:\/\/www.amazon.fr\/Tefal-C3671002-El%C3%A9gance-Cr%C3%AApi%C3%A8re-Aluminium\/dp\/B0771LN5TC\/?mt-u-240-21","brand_id":163,"brand_name":"Amazon"}]
#  });
#   </script>
#   <script type="text/javascript">
#    var appBlock = new MrtnBlock();
#  appBlock.init({
#  blockClassName: "recipe-utensils__list",
#  actionGA: "UtensilsBlock - Display - Sampling 10%",
#  sampling: 10
#  });
#   </script>
#   <script type="text/javascript">
#    var appSButtonsV2 = appSButtonsV2 || {};
#
# jquery$(function() {
#  var sBtnInfos = {
#  isMobile: false,
#  shareImg: null,
#  shareProviders: ["facebook","twitter","pinterest","mail"],
#  shareTitle: "",
#  shareUrl: null,
#  initOpen: true,
#  providers: {
#  facebook: {
#  pageURL: "https:\/\/www.facebook.com\/marmiton",
#  showLikeButton: null,
#  url: " https:\/\/www.facebook.com\/dialog\/feed?app_id=179380945463734&display=popup&redirect_uri=https:\/\/www.marmiton.org\/reloaded\/followUs\/facebook&link=",
#  urlFollowUs: "https:\/\/www.marmiton.org\/reloaded\/followUs\/facebook"
#  },
#  pinterest: {
#  urlFollowUs: "https:\/\/www.marmiton.org\/reloaded\/followUs\/pinterest",
#  shareImg:null
#  }
#  }
#  };
#  appSButtonsV2["af-socials-btn-diapo-desktop-0"] = new AufSButtonsV2();
#  appSButtonsV2["af-socials-btn-diapo-desktop-0"].init("af-socials-btn-diapo-desktop-0", "diapoDesktop", sBtnInfos);
# });
#   </script>
#   <script type="text/javascript">
#    var af_rating_component = ''
#   </script>
#   <script type="text/javascript">
#    af_addEvent(window, 'scroll', af_lazyloading, false);
#  af_addEvent(window, 'load', af_lazyloading, false);
#   </script>
#   <script type="text/javascript">
#    var cookbookModalMessages={"status_200":{"message":"La recette a \u00e9t\u00e9 ajout\u00e9e au carnet","link":"http:\/\/www.google.fr"},"status_400":{"message":"Une erreur est survenue durant l'ajout au carnet"}};
#
#  if(Mrtn && Mrtn.USER && Mrtn.USER.id) {
#  var cookbookAddModal = new Mrtn.CookbookAddModal();
#  }
#   </script>
#   <script type="text/javascript">
#    var done = false;
#  var callback = function printCallback() {
#  try {
#  if (typeof Mrtn !== 'undefined' && typeof Mrtn.cookbooks !== 'undefined' && Mrtn.cookbooks.cookbooks.Settings) {
#  var printedReviewCount = Mrtn.cookbooks.cookbooks.Settings.PrintedReviewCount;
#  if (printedReviewCount == 1) {
#  var reviews = document.getElementById('recipe-reviews-list-bloc');
#  reviews.classList.remove('mrtn-hide-on-print');
#  }
#  }
#  done = true;
#  }
#  catch(e) {
#  console.log(e);
#  }
#  };
#
#  if (typeof Mrtn !== 'undefined' &&
#  typeof Mrtn.cookbooks !== 'undefined' &&
#  Mrtn.USER) {
#  Mrtn.cookbooks.getUserCookbooks( {user:Mrtn.USER, callback:callback});
#  }
#
#  if (!done && (typeof Mrtn === 'undefined' || !Mrtn.USER || typeof Mrtn.cookbooks === 'undefined')) {
#  callback();
#  }
#   </script>
#   <script type="text/javascript">
#    var appAufStickyCol = appAufStickyCol || {};
#  document.addEventListener("DOMContentLoaded", function() {
#  appAufStickyCol["sticky-col-right"] = new AfStickyCol();
#  appAufStickyCol["sticky-col-right"].init({
#  id: "sticky-col-right",
#  superParent: true,
#  bottomCtn: document.getElementById("sticky-desktop-only")
#  });
#  });
#   </script>
#   <script type="text/javascript">
#    af_addEvent(window, 'beforeunload', function () {
#  var srcNodeList = document.querySelectorAll('[src]');
#  for (var i = 0; i < srcNodeList.length; ++i) {
#  var url = srcNodeList[i].getAttribute('src');
#  if (url.substring(0,5) == 'http:') {
#  afLogger.logError('Insecure call to: ' + url);
#  }
#  }
#  });
#   </script>
#   <script type="text/javascript">
#    af_addEvent(window, 'load', function() {
#  var header = document.getElementById('header');
#  if (header && header.offsetHeight > 500) {
#  afLogger.logError('CSS fucked - check concat', 'PHP');
#  }
#  });
#   </script>
#   <script type="text/javascript">
#    window.afPageSpeedLogger = new AfPageSpeedLogger();
#   </script>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({"gtm.start":
#  new Date().getTime(),event:"gtm.js"});var f=d.getElementsByTagName(s)[0],
#  j=d.createElement(s),dl=l!="dataLayer"?"&l="+l:"";j.async=true;j.src=
#  "https://www.googletagmanager.com/gtm.js?id="+i+dl;f.parentNode.insertBefore(j,f);
#  })(window,document,"script","m_dataLayer","GTM-MX2D67");
#   </script>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MX2D67" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-aedcd3c03fde7213bd0","applicationID":"409934563","transactionName":"YAQHMUtYWUQDWkVaC1lOJAZNUFhZTUtUUA1HBEoXXFpeRwd4QkMc","queueTime":0,"applicationTime":121,"atts":"TEMERwNCSko=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %% [markdown]
# Voici ce que nous obtenons de la fonction prettify ():

# %% [markdown]
#                                 <!DOCTYPE html>
#                                 <html class="client-nojs" dir="ltr" lang="en">
#                                  <head>
#                                   <meta charset="utf-8"/>
#                                   <title>
#                                    List of European countries by area - Wikipedia
#                                   </title>
#                                   <script>

# %% [markdown]
# Si vous visitez le lien et consultez notre page Wikipedia pour les pays asiatiques, vous constaterez qu’il existe un peu plus d’informations sur les régions. La table wikipedia déjà configurée rend notre travail plus facile.Jetons un coup d’œil à cela dans notre joli HTML:

# %% [markdown]
# Et voilà, en commençant par une balise HTML $<table>$ avec un identifiant de classe «wikitable sortable». Nous nous souviendrons de cette classe pour une utilisation future. Si vous descendez dans votre programme, vous verrez comment la table est composée, et vous verrez les lignes commençant et se terminant par les balises $<tr>$ et $</ tr>$.
#
# La première rangée d'en-têtes a des balises $<th>$ tandis que les rangées de données en dessous de chaque club ont des balises $<td>$. Utilisation des balises $<td>$ que nous allons demander à Python de sécuriser nos données.

# %% [markdown]
# Nous pouvons utiliser ces informations pour préparer notre attaque contre le HTML.Nous savons que les données restent dans une table HTML. Nous demandons donc à Beautiful Soup de récupérer toutes les occurrences de la balise $<table>$ dans la page et de les ajouter à un tableau appelé all_tables.

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
html_bloc_ing = html_parsé.find('ul',{'class':"recipe-ingredients__list"})
# Out:
# <ul class="recipe-ingredients__list">
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67727_w100h100c1cx350cy350.jpg"><div><span class="recipe-ingredient-qt" data-base-qt="8">8</span>
# <p class="name_singular" data-name-singular=" tortilla" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" tortillas" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="pour tacos (achetés, ou recette sur le site Marmiton)" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="pour tacos (achetés, ou recette sur le site Marmiton)" style="display: none;"></p><span class="ingredient"> tortillas</span><span class="recipe-ingredient__complement"> pour tacos (achetés, ou recette sur le site Marmiton)</span></div> </img></li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67525_w100h100c1cx350cy350.jpg"><div><span class="recipe-ingredient-qt" data-base-qt="1">1</span>
# <p class="name_singular" data-name-singular=" oignon blanc" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" oignons blancs" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient"> oignon blanc</span><span class="recipe-ingredient__complement"> </span></div> </img></li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67459_w100h100c1cx350cy350.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="2">2</span>
# <p class="name_singular" data-name-singular=" tomate" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" tomates" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient"> tomates</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67657_w100h100c1cx350cy350.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="1">1</span>
# <p class="name_singular" data-name-singular="verre de coulis de tomate" style="display: none;"></p>
# <p class="name_plural" data-name-plural="verres de coulis de tomate" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="(10 cl)" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="(10 cl)" style="display: none;"></p><span class="ingredient">verre de coulis de tomate</span><span class="recipe-ingredient__complement"> (10 cl)</span></div> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67692_w100h100c1cx350cy350.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="250">250</span>
# <p class="name_singular" data-name-singular="g de boeuf haché" style="display: none;"></p>
# <p class="name_plural" data-name-plural="g de boeuf haché" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">g de boeuf haché</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67674_w100h100c1cx350cy350.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="1">1</span>
# <p class="name_singular" data-name-singular="petite boîte de haricots rouges" style="display: none;"></p>
# <p class="name_plural" data-name-plural="petites boîtes de haricots rouges" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">petite boîte de haricots rouges</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20180404/78364_w100h100c1cx3432cy3432cxt0cyt0cxb6864cyb6864.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="0.5">1/2</span>
# <p class="name_singular" data-name-singular=" poivron vert" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" poivrons verts" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient"> poivron vert</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20171229/76431_w100h100c1cx1800cy1750cxt0cyt0cxb3600cyb3500.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt="8">8</span>
# <p class="name_singular" data-name-singular="feuille de laitue" style="display: none;"></p>
# <p class="name_plural" data-name-plural="feuilles de laitue" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">feuilles de laitue</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item recipe-ingredients__list__item--prog" id="recipe-ingredients__0__8">
# <a href="https://www.amazon.fr/Cumin-poudre-jeera-50/dp/B00HF9XJMA/?tag=mt-i-1558-21" onclick="recordInternalLinkGA('OPS', 'Recipe - BrandIngredient - Click', '[Amazon] 1558 - cumin en poudre')" target="_blank"><img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170621/69021_w100h100c1cxt0cyt0cxb700cyb700.jpg"/><div class="recipe-ingredients__list__item--prog-content"><div><span class="recipe-ingredient-qt" data-base-qt=""></span>
# <p class="name_singular" data-name-singular=" cumin en poudre" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" cumin en poudre" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">Cumin en poudre</span><span class="recipe-ingredient__complement"> </span></div></div></a> </li>
# <li class="recipe-ingredients__list__item">
# <img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67563_w100h100c1cx350cy350.jpg"/><div><span class="recipe-ingredient-qt" data-base-qt=""></span>
# <p class="name_singular" data-name-singular=" poivre" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" poivre" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">Poivre</span><span class="recipe-ingredient__complement"> </span></div> </li>
# <li class="recipe-ingredients__list__item recipe-ingredients__list__item--prog" id="recipe-ingredients__0__10">
# <a href="https://www.amazon.fr/Rose-Naturel-lHimalaya-Pipkin-500g/dp/B0772X3JXY?tag=mt-i-990-21" onclick="recordInternalLinkGA('OPS', 'Recipe - BrandIngredient - Click', '[Amazon] 990 - sel')" target="_blank"><img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67687_w100h100c1cx350cy350.jpg"/><div class="recipe-ingredients__list__item--prog-content"><div><span class="recipe-ingredient-qt" data-base-qt=""></span>
# <p class="name_singular" data-name-singular=" sel" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" sel" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="" style="display: none;"></p><span class="ingredient">Sel</span><span class="recipe-ingredient__complement"> </span></div></div></a> </li>
# <li class="recipe-ingredients__list__item recipe-ingredients__list__item--prog" id="recipe-ingredients__0__11">
# <a href="https://www.amazon.fr/Tabasco-9574-Salsa-Picante-60g/dp/B00XIJK5SC?tag=mt-i-1237-21" onclick="recordInternalLinkGA('OPS', 'Recipe - BrandIngredient - Click', '[Amazon] 1237 - tabasco')" target="_blank"><img class="ingredients-list__item__icon" src="https://assets.afcdn.com/recipe/20170607/67548_w100h100c1cx350cy350.jpg"/><div class="recipe-ingredients__list__item--prog-content"><div><span class="recipe-ingredient-qt" data-base-qt=""></span>
# <p class="name_singular" data-name-singular=" tabasco" style="display: none;"></p>
# <p class="name_plural" data-name-plural=" tabasco" style="display: none;"></p>
# <p class="complement_singular" data-complement-singular="(facultatif)" style="display: none;"></p>
# <p class="complement_plural" data-complement-plural="(facultatif)" style="display: none;"></p><span class="ingredient">Tabasco</span><span class="recipe-ingredient__complement"> (facultatif)</span></div></div></a> </li>
# </ul>

# %% [markdown]
# Sous la classe de table ‘wikitable triable’, nous avons des liens avec le nom du pays comme titre.

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
html_list_ing = html_bloc_ing.findAll('li', {'class':"recipe-ingredients__list__item"})
html_list_ing
# Out:
# '\n8\n\n\n\n tortillas pour tacos (achetés, ou recette sur le site Marmiton) '

# %% [markdown]
# Sous la classe de table ‘wikitable triable’, nous avons des liens avec le nom du pays comme titre. Nous allons maintenant extraire tous les liens contenus dans $<a>$, nous avons utilisé find_all ().

# %% [markdown]
# De l'URL, nous devons extraire le titre qui est le nom des pays. Pour ce faire, nous devons créer une liste Pays afin de pouvoir extraire le nom des pays du lien et l'ajouter à la liste des pays.

# %%
ings = []
for html_ing in html_list_ing:
    print(html_ing.text.replace('\n',''))
    #ings.append(html_ing.text)
    #producer.send('wiki_countries', {'href': link.get('href'), 'name': link.get('title')})
    
#print(ings)
# Out:
# 8 tortillas pour tacos (achetés, ou recette sur le site Marmiton)
# 1 oignon blanc
# 2 tomates
# 1verre de coulis de tomate (10 cl)
# 250g de boeuf haché
# 1petite boîte de haricots rouges
# 1/2 poivron vert
# 8feuilles de laitue
# Cumin en poudre
# Poivre
# Sel
# Tabasco (facultatif)

# %% [markdown]
# Maintenant, nous devons convertir les pays de la liste en Pandas DataFrame pour qu’ils fonctionnent en python.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Et cela nous mène à la fin de notre tutoriel Beautiful Soup. En toute confiance, cela vous fournit assez de travail pour examiner certains problèmes pour votre prochain projet. Nous avons introduit une requête pour extraire l’URL et les données HTML, Beautiful Soup pour analyser le code HTML et des pandas pour convertir les données en un bloc de données pour une présentation correcte.
